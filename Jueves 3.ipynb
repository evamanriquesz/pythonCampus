# %% [markdown]
# # GRÁFICAS:

# %%
import matplotlib.pyplot as plt

# %%
# Grafico de lineas

# %%
x = [2, 3, 5, 6, 8]
y = [1, 5, 6, 8, 10]

# %%
plt.plot(x, y)
plt.grid()

# %%
plt.plot(x, y, color ="green")

# %%
plt.plot(x, y, color ="green", linestyle="--")

# %%
plt.plot(x, y, color ="green", linestyle="--", linewidth =5)

# %%
x = [2, 3, 5, 6, 8]
y = [1, 5, 6, 8, 10]

x2 = [1,4, 5, 7,8]
y2 = [7, 12, 15, 17, 20]

plt.plot(x, y, color ="green", linestyle="--", linewidth =5)
plt.plot(x2, y2, color ="red", linestyle="--", linewidth =2)

# %%
plt.plot(x, y, color ="green", linestyle="--", linewidth =5, label="Clase1")
plt.plot(x2, y2, color ="red", linestyle="--", linewidth =2, label="Clase2")
plt.legend(loc = "upper left")
plt.title("Grafico de lineas de prueba")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
# Out:
# Text(0, 0.5, 'Eje Y')

# %%
# Grafico de barras

# %%
x = [2, 3, 5, 6, 8]
y = [1, 5, 6, 8, 10]

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(x, y, color='green')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(x, y, color='green', width=3)
# Out:
# <BarContainer object of 5 artists>

# %%
#Grafico circular
labels = ["A", 'B', 'C', 'D', 'E']
sizes = [5, 12, 16, 26, 45]
colors = ['gold', 'yellowgreen','pink', 'lightcoral', 'lightskyblue']
plt.pie(sizes, labels = labels, colors = colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x21a4a09d490>,
# ...
#  [Text(1.0874769529812804, 0.16551095653928846, 'A'),
#   Text(0.8659018237841455, 0.6783907661276728, 'B'),
#   Text(0.06641631751022606, 1.0979931114394028, 'C'),
#   Text(-1.028517884511915, 0.39006532945025413, 'D'),
#   Text(0.2308692994117026, -1.0754995893021764, 'E')])

# %%
# EJERCICIO

# %%
productos =  ['camisa', 'pantalon', 'falda', 'bermudas']
semana1 = [150, 100, 200, 10]
semana2 = [80, 20, 50, 30]
semana3 = [160, 20, 120, 60]
semana4 = [10, 190, 30, 130]
