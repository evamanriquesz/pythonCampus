# %% [markdown]
# # Gráficas

# %% [markdown]
# https://matplotlib.org/stable/plot_types/index

# %%
import matplotlib.pyplot as plt

# %%
x = [2, 3, 5, 6, 8]
y = [1, 5, 6, 8, 10]

# %%
# Grafico de lineas

plt.plot(x,y)

# %%
plt.plot(x, y, color = 'green')

# %%
plt.plot(x,y,color = 'green', linestyle = "--")

# %%
plt.plot(x,y,color = 'green', linestyle = "--", linewidth = 5)

# %%
x = [2, 3, 5, 6, 8]
y = [1, 5, 6, 8, 10]
y2 = [4,6,8,9, 13]

# %%
plt.plot(x,y,color = 'green', linestyle = "--", linewidth = 5)
plt.plot(x,y2,color = 'red', linestyle = "--", linewidth = 3)

# %%
plt.plot(x,y,color = 'green', linestyle = "--", linewidth = 5, label = "Linea verde")
plt.plot(x,y2,color = 'red', linestyle = "--", linewidth = 3, label = "Linea roja")
plt.title("Grafico de lineas")
plt.xlabel("Eje X")
plt.ylabel("Eye Y")
plt.legend(loc = "upper left")

# %%
plt.plot(x,y,color = 'green', linestyle = "--", linewidth = 5, label = "Linea verde")
plt.plot(x,y2,color = 'red', linestyle = "--", linewidth = 3, label = "Linea roja")
plt.title("Grafico de lineas")
plt.xlabel("Eje X")
plt.ylabel("Eye Y")
plt.legend(loc = "upper right")

# %%
# Gráfico de barras

x = [2, 3, 5, 6, 8]
y = [1, 5, 6, 8, 10]

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(x,y, color = "green")
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(x, y, width = 0.1)
# Out:
# <BarContainer object of 5 artists>

# %%
# Grafico de sectores (pie(x))

labels = ["A", 'B', 'C', 'D', 'E']
sizes = [5, 12, 16, 26, 45]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
plt.pie(sizes, labels = labels, colors = colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x27d472de4f0>,
# ...
#  [Text(1.0874769529812804, 0.16551095653928846, 'A'),
#   Text(0.8659018237841455, 0.6783907661276728, 'B'),
#   Text(0.06641631751022606, 1.0979931114394028, 'C'),
#   Text(-1.028517884511915, 0.39006532945025413, 'D'),
#   Text(0.2308692994117026, -1.0754995893021764, 'E')])

# %% [markdown]
# # Ejercicio - Graficos de productos

# %%
productos =  ['camisa', 'pantalon', 'falda', 'bermudas']
semana1 = [150, 100, 200, 10]
semana2 = [80, 20, 50, 30]
semana3 = [160, 20, 120, 60]
semana4 = [10, 190, 30, 130]

# %%
# Imprimir todas las semanas en un grafico de lineas en diferentes colores, con leyenda, titulos, etc 

plt.plot(productos, semana1, color = "green", linestyle = "--", linewidth = 1, label = "Semana 1")
plt.plot(productos, semana2, color = "blue", linewidth = 2, label = "Semana 2")
plt.plot(productos, semana3, color = "red", linestyle = "--", linewidth = 3, label = "Semana 3")
plt.plot(productos, semana4, color = "yellow",  linewidth = 4, label = "Semana 4")

# %%
# Imprimir todas las semanas en un grafico de barras en diferentes colores, con leyenda, titulos, difernetes tamaños, etc

# %%
# Imprimir cada semana en un pie

# %% [markdown]
# # Dataframes

# %% [markdown]
# https://pandas.pydata.org/docs/user_guide/index.html

# %%
import pandas as pd

# Crear un diccionario con los datos
data = {
    'Nombre': ['Pelota', 'Muñeca', 'Camión', 'Rompecabezas', 'Lego'],
    'Tipo': ['Deporte', 'Figura', 'Vehículo', 'Juego de mesa', 'Construcción'],
    'Precio': [5, 10, 7, 12, 15],
    'Stock': [50, 30, 20, 10, 15]
}

# Crear el dataframe
df = pd.DataFrame(data)

# Mostrar el dataframe
print(df)
# Out:
#          Nombre           Tipo  Precio  Stock
# 0        Pelota        Deporte       5     50
# 1        Muñeca         Figura      10     30
# 2        Camión       Vehículo       7     20
# 3  Rompecabezas  Juego de mesa      12     10
# 4          Lego   Construcción      15     15

# %%
df
# Out:
#          Nombre           Tipo  Precio  Stock
# 0        Pelota        Deporte       5     50
# 1        Muñeca         Figura      10     30
# 2        Camión       Vehículo       7     20
# 3  Rompecabezas  Juego de mesa      12     10
# 4          Lego   Construcción      15     15

# %%
# En un df largo, para ver las primeras filas: 
df.head()
# Out:
#          Nombre           Tipo  Precio  Stock
# 0        Pelota        Deporte       5     50
# 1        Muñeca         Figura      10     30
# 2        Camión       Vehículo       7     20
# 3  Rompecabezas  Juego de mesa      12     10
# 4          Lego   Construcción      15     15

# %%
#Seleccionar una columna 
print(df['Nombre'])
# Out:
# 0          Pelota
# 1          Muñeca
# 2          Camión
# 3    Rompecabezas
# 4            Lego
# Name: Nombre, dtype: object

# %%
#Filtrar por una condicion
productos_caros = df[df['Precio'] > 10]
print(productos_caros)
# Out:
#          Nombre           Tipo  Precio  Stock
# 3  Rompecabezas  Juego de mesa      12     10
# 4          Lego   Construcción      15     15

# %%
# Añadir una nueva columna 
df['Precio con IVA'] = df['Precio'] * 1.21
print(df)
# Out:
#          Nombre           Tipo  Precio  Stock  Precio con IVA
# 0        Pelota        Deporte       5     50            6.05
# 1        Muñeca         Figura      10     30           12.10
# 2        Camión       Vehículo       7     20            8.47
# 3  Rompecabezas  Juego de mesa      12     10           14.52
# 4          Lego   Construcción      15     15           18.15

# %%
# Ordenar por una columna
df_sorted = df.sort_values(by='Precio')
print(df_sorted)
# Out:
#          Nombre           Tipo  Precio  Stock  Precio con IVA
# 0        Pelota        Deporte       5     50            6.05
# 2        Camión       Vehículo       7     20            8.47
# 1        Muñeca         Figura      10     30           12.10
# 3  Rompecabezas  Juego de mesa      12     10           14.52
# 4          Lego   Construcción      15     15           18.15

# %%
# Agrupar por 'Tipo' y calcular la media del 'Precio'
grouped = df.groupby('Tipo')['Precio'].mean()
print(grouped)
# Out:
# Tipo
# Construcción     15
# Deporte           5
# Figura           10
# Juego de mesa    12
# Vehículo          7
# Name: Precio, dtype: int64

# %% [markdown]
# ### Cargar desde un CSV

# %%
df_loaded = pd.read_csv("productos.csv", encoding = "latin1", delimiter = ";")

# %%
df_loaded.head()
# Out:
#                     PRODUCTO       PRECIO
# 0        Lavadora Automatica  810,6362913
# 1  Refrigerador Doble Puerta  683,0692759
# 2           Horno Microondas  670,0098671
# 3         Cafetera Eléctrica   502,027545
# 4           Plancha de Vapor  721,1030919

# %% [markdown]
# ### Guardar a un CSV

# %%
# Lo guardamos en CSV 
df_loaded.to_csv('productos_nuevo.csv', index=False, encoding='latin1', sep=';')
